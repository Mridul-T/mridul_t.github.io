# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import matplotlib.animation as animation

# %%
with open('results_pce_21_new.pkl', 'rb') as file:
    ut = pickle.load(file)
# with open('ut_det.pkl', 'rb') as file:
#     ut2 = pickle.load(file)
with open('results_pce_21_new.pkl', 'rb') as file:
    coords = pickle.load(file)
# with open('coords_det.pkl', 'rb') as file:
#     coords2 = pickle.load(file)

# %%
J=2500
# J=10000

# %%
ut.shape
# Out:
# (2, 496, 2500, 101)

# %%
coords.shape
# Out:
# (2, 496, 2500, 101)

# %%
np.sum(abs(ut[1,0,:,:])>1e2)
# Out:
# 0

# %%
plt.subplots(figsize=(20, 4))
u_plot=ut[1,0,:,0].reshape((int(np.sqrt(J)), int(np.sqrt(J))))
plt.subplot(1,5,1)
heatmap=plt.imshow(u_plot, aspect='auto', cmap='jet')
plt.xlabel('Spatial dimension (y)')
plt.ylabel('Spatial dimension (x)')
plt.title(f'at time {0}', fontweight='bold')
cbar = plt.colorbar(heatmap)
plt.subplot(1,5,2)
u_plot=np.flip(ut[1,0,:,25]).reshape((int(np.sqrt(J)), int(np.sqrt(J)))).T
heatmap=plt.imshow(u_plot, aspect='auto', cmap='jet')
plt.xlabel('Spatial dimension (y)')
plt.ylabel('Spatial dimension (x)')
plt.title(f'at time {0.075}', fontweight='bold')
cbar = plt.colorbar(heatmap)
plt.subplot(1,5,3)
u_plot=np.flip(ut[1,0,:,50]).reshape((int(np.sqrt(J)), int(np.sqrt(J)))).T
heatmap=plt.imshow(u_plot, aspect='auto', cmap='jet')
plt.xlabel('Spatial dimension (y)')
plt.ylabel('Spatial dimension (x)')
plt.title(f'at time {0.150}', fontweight='bold')
cbar = plt.colorbar(heatmap)
plt.subplot(1,5,4)
u_plot=np.flip(ut[1,0,:,75]).reshape((int(np.sqrt(J)), int(np.sqrt(J)))).T
heatmap=plt.imshow(u_plot, aspect='auto', cmap='jet')
plt.xlabel('Spatial dimension (y)')
plt.ylabel('Spatial dimension (x)')
plt.title(f'at time {0.225}', fontweight='bold')
cbar = plt.colorbar(heatmap)
plt.subplot(1,5,5)
u_plot=np.flip(ut[1,0,:,100]).reshape((int(np.sqrt(J)), int(np.sqrt(J)))).T
heatmap=plt.imshow(u_plot, aspect='auto', cmap='jet')
plt.xlabel('Spatial dimension (y)')
plt.ylabel('Spatial dimension (x)')
plt.title(f'at time {0.300}', fontweight='bold')
cbar = plt.colorbar(heatmap)
# Add colorbar with legend
# cbar = plt.colorbar(heatmap)
# Save the figure
plt.savefig('u_mean_pce2_1.png', dpi=300, bbox_inches='tight')

cbar.set_label('Values')
plt.show()

# %%
# plt.subplots(figsize=(20, 4))
# u_plot=ut[1,0,:,:,0]
# plt.subplot(1,5,1)
# heatmap=plt.imshow(u_plot, aspect='auto', cmap='jet')
# plt.xlabel('Spatial dimension (y)')
# plt.ylabel('Spatial dimension (x)')
# plt.title(f'at time {0}', fontweight='bold')
# cbar = plt.colorbar(heatmap)
# plt.subplot(1,5,2)
# u_plot=ut[1,0,:,:,100]
# heatmap=plt.imshow(u_plot, aspect='auto', cmap='jet')
# plt.xlabel('Spatial dimension (y)')
# plt.ylabel('Spatial dimension (x)')
# plt.title(f'at time {0.02}', fontweight='bold')
# cbar = plt.colorbar(heatmap)
# plt.subplot(1,5,3)
# u_plot=ut[1,0,:,:,200]
# heatmap=plt.imshow(u_plot, aspect='auto', cmap='jet')
# plt.xlabel('Spatial dimension (y)')
# plt.ylabel('Spatial dimension (x)')
# plt.title(f'at time {0.04}', fontweight='bold')
# cbar = plt.colorbar(heatmap)
# plt.subplot(1,5,4)
# u_plot=ut[1,0,:,:,300]
# heatmap=plt.imshow(u_plot, aspect='auto', cmap='jet')
# plt.xlabel('Spatial dimension (y)')
# plt.ylabel('Spatial dimension (x)')
# plt.title(f'at time {0.06}', fontweight='bold')
# cbar = plt.colorbar(heatmap)
# plt.subplot(1,5,5)
# u_plot=ut[1,0,:,:,300]
# heatmap=plt.imshow(u_plot, aspect='auto', cmap='jet')
# plt.xlabel('Spatial dimension (y)')
# plt.ylabel('Spatial dimension (x)')
# plt.title(f'at time {0.08}', fontweight='bold')
# cbar = plt.colorbar(heatmap)
# # Add colorbar with legend
# # cbar = plt.colorbar(heatmap)
# cbar.set_label('Values')
# plt.show()

# %%
# plt.subplots(figsize=(20, 4))
# u_plot=ut2[1,:,0].reshape((int(np.sqrt(J)), int(np.sqrt(J))))
# plt.subplot(1,5,1)
# heatmap=plt.imshow(u_plot, aspect='auto', cmap='jet')
# plt.xlabel('Spatial dimension (y)')
# plt.ylabel('Spatial dimension (x)')
# plt.title(f'at time {0}', fontweight='bold')
# cbar = plt.colorbar(heatmap)
# plt.subplot(1,5,2)
# u_plot=ut2[1,:,10].reshape((int(np.sqrt(J)), int(np.sqrt(J))))
# heatmap=plt.imshow(u_plot, aspect='auto', cmap='jet')
# plt.xlabel('Spatial dimension (y)')
# plt.ylabel('Spatial dimension (x)')
# plt.title(f'at time {0.02}', fontweight='bold')
# cbar = plt.colorbar(heatmap)
# plt.subplot(1,5,3)
# u_plot=ut2[1,:,20].reshape((int(np.sqrt(J)), int(np.sqrt(J))))
# heatmap=plt.imshow(u_plot, aspect='auto', cmap='jet')
# plt.xlabel('Spatial dimension (y)')
# plt.ylabel('Spatial dimension (x)')
# plt.title(f'at time {0.04}', fontweight='bold')
# cbar = plt.colorbar(heatmap)
# plt.subplot(1,5,4)
# u_plot=ut2[1,:,30].reshape((int(np.sqrt(J)), int(np.sqrt(J))))
# heatmap=plt.imshow(u_plot, aspect='auto', cmap='jet')
# plt.xlabel('Spatial dimension (y)')
# plt.ylabel('Spatial dimension (x)')
# plt.title(f'at time {0.06}', fontweight='bold')
# cbar = plt.colorbar(heatmap)
# plt.subplot(1,5,5)
# u_plot=ut2[1,:,60].reshape((int(np.sqrt(J)), int(np.sqrt(J))))
# heatmap=plt.imshow(u_plot, aspect='auto', cmap='jet')
# plt.xlabel('Spatial dimension (y)')
# plt.ylabel('Spatial dimension (x)')
# plt.title(f'at time {0.08}', fontweight='bold')
# cbar = plt.colorbar(heatmap)
# # Add colorbar with legend
# # cbar = plt.colorbar(heatmap)
# cbar.set_label('Values')
# plt.show()

# %%
u_std=0
for i in range(1,ut.shape[1]):
    u_std+=ut[:,i,:,:]**2
u_std=np.sqrt(u_std)

# %%
np.sum(u_std[1,:,50].reshape((int(np.sqrt(J)), int(np.sqrt(J)))) > 1e5)
# Out:
# 0

# %%
plt.subplots(figsize=(20, 4))
u_plot=u_std[1,:,0].reshape((int(np.sqrt(J)), int(np.sqrt(J))))
plt.subplot(1,5,1)
heatmap=plt.imshow(u_plot, aspect='auto', cmap='jet')
plt.xlabel('Spatial dimension (y)')
plt.ylabel('Spatial dimension (x)')
plt.title(f'at time {0}', fontweight='bold')
cbar = plt.colorbar(heatmap)
plt.subplot(1,5,2)
u_plot=u_std[1,:,25].reshape((int(np.sqrt(J)), int(np.sqrt(J))))
heatmap=plt.imshow(u_plot, aspect='auto', cmap='jet')
plt.xlabel('Spatial dimension (y)')
plt.ylabel('Spatial dimension (x)')
plt.title(f'at time {0.075}', fontweight='bold')
cbar = plt.colorbar(heatmap)
plt.subplot(1,5,3)
u_plot=u_std[1,:,50].reshape((int(np.sqrt(J)), int(np.sqrt(J))))
heatmap=plt.imshow(u_plot, aspect='auto', cmap='jet')
plt.xlabel('Spatial dimension (y)')
plt.ylabel('Spatial dimension (x)')
plt.title(f'at time {0.15}', fontweight='bold')
cbar = plt.colorbar(heatmap)
plt.subplot(1,5,4)
u_plot=u_std[1,:,75].reshape((int(np.sqrt(J)), int(np.sqrt(J))))
heatmap=plt.imshow(u_plot, aspect='auto', cmap='jet')
plt.xlabel('Spatial dimension (y)')
plt.ylabel('Spatial dimension (x)')
plt.title(f'at time {0.225}', fontweight='bold')
cbar = plt.colorbar(heatmap)
plt.subplot(1,5,5)
u_plot=u_std[1,:,100].reshape((int(np.sqrt(J)), int(np.sqrt(J))))
heatmap=plt.imshow(u_plot, aspect='auto', cmap='jet')
plt.xlabel('Spatial dimension (y)')
plt.ylabel('Spatial dimension (x)')
plt.title(f'at time {0.30}', fontweight='bold')
cbar = plt.colorbar(heatmap)
# Add colorbar with legend
# cbar = plt.colorbar(heatmap)
# Save the figure
plt.savefig('u_std_pce2_1.png', dpi=300, bbox_inches='tight')

cbar.set_label('Values')
plt.show()

# %%
u_std.shape
# Out:
# (2, 2500, 101)

# %%
# plt.subplots(figsize=(20, 4))
# u_plot=u_std[1,:,:0]
# plt.subplot(1,5,1)
# heatmap=plt.imshow(u_plot, aspect='auto', cmap='jet')
# plt.xlabel('Spatial dimension (y)')
# plt.ylabel('Spatial dimension (x)')
# plt.title(f'at time {0}', fontweight='bold')
# cbar = plt.colorbar(heatmap)
# plt.subplot(1,5,2)
# u_plot=u_std[1,:,:,10]
# heatmap=plt.imshow(u_plot, aspect='auto', cmap='jet')
# plt.xlabel('Spatial dimension (y)')
# plt.ylabel('Spatial dimension (x)')
# plt.title(f'at time {0.05}', fontweight='bold')
# cbar = plt.colorbar(heatmap)
# plt.subplot(1,5,3)
# u_plot=u_std[1,:,:,20]
# heatmap=plt.imshow(u_plot, aspect='auto', cmap='jet')
# plt.xlabel('Spatial dimension (y)')
# plt.ylabel('Spatial dimension (x)')
# plt.title(f'at time {0.10}', fontweight='bold')
# cbar = plt.colorbar(heatmap)
# plt.subplot(1,5,4)
# u_plot=u_std[1,:,:,30]
# heatmap=plt.imshow(u_plot, aspect='auto', cmap='jet')
# plt.xlabel('Spatial dimension (y)')
# plt.ylabel('Spatial dimension (x)')
# plt.title(f'at time {0.15}', fontweight='bold')
# cbar = plt.colorbar(heatmap)
# plt.subplot(1,5,5)
# u_plot=u_std[1,:,:,40]
# heatmap=plt.imshow(u_plot, aspect='auto', cmap='jet')
# plt.xlabel('Spatial dimension (y)')
# plt.ylabel('Spatial dimension (x)')
# plt.title(f'at time {0.20}', fontweight='bold')
# cbar = plt.colorbar(heatmap)
# # Add colorbar with legend
# # cbar = plt.colorbar(heatmap)
# cbar.set_label('Values')
# plt.show()

# %%
# from matplotlib.animation import FuncAnimation
# import matplotlib.animation as animation
# plt.rcParams['font.family'] = 'Times New Roman'
# plt.rcParams['font.size'] = 12
# plt.rcParams['mathtext.fontset'] = 'dejavuserif'
# # Create a figure and axis
# fig, ax = plt.subplots(figsize=(12, 10))
# def update_plot(frame):
#     ax.clear()
#     global coords
#     coords_cpu = coords[0,:,:,frame]
#     colors = ['red']

    
#     ax.clear()
#     ax.scatter(coords_cpu[:, 0], coords_cpu[:, 1], c=colors)
#     ax.set_title(f"Scatter Plot of both boxes at time step {frame*2}")
#     ax.set_xlabel("X coordinate")
#     ax.set_ylabel("Y coordinate")
    
    
#     ax.set_aspect('equal', adjustable='box')  # Set uniform scale
#     ax.axvline(x=0, color='gray', linestyle='--')  # Add a vertical line at x = 0
#     # plt.show()

# anim = FuncAnimation(fig, update_plot, frames=coords.shape[3], interval=50)

# anim.save('coords_pce.gif', writer=animation.PillowWriter(fps=60))

# # Display the animation
# plt.show()

# %%
# from matplotlib.animation import FuncAnimation
# import matplotlib.animation as animation
# plt.rcParams['font.family'] = 'Times New Roman'
# plt.rcParams['font.size'] = 12
# plt.rcParams['mathtext.fontset'] = 'dejavuserif'
# # Create a figure and axis
# fig, ax = plt.subplots(figsize=(12, 10))
# def update_plot(frame):
#     ax.clear()
#     global coords2
#     coords_cpu = coords2[:,:,frame]
#     colors = ['red']

    
#     ax.clear()
#     ax.scatter(coords_cpu[:, 0], coords_cpu[:, 1], c=colors)
#     ax.set_title(f"Scatter Plot of both boxes at time step {frame*2}")
#     ax.set_xlabel("X coordinate")
#     ax.set_ylabel("Y coordinate")
    
    
#     ax.set_aspect('equal', adjustable='box')  # Set uniform scale
#     ax.axvline(x=0, color='gray', linestyle='--')  # Add a vertical line at x = 0
#     # plt.show()

# anim = FuncAnimation(fig, update_plot, frames=coords2.shape[2], interval=50)

# anim.save('coords_det.gif', writer=animation.PillowWriter(fps=60))

# # Display the animation
# plt.show()
