# %% [markdown]
# ### We first need to define probabilistic orthonormal hermite polynomials for standard Gaussian as well as define the corresponding scalar product and triple product

# %%
import numpy as np
from scipy.special import hermite
from scipy.integrate import quad ## FUNCTIONS TO IMPLEMENT GAUSS-QUADRATURE
from scipy.integrate import quad_vec ## FUNCTIONS TO IMPLEMENT GAUSS-QUADRATURE
import matplotlib.pyplot as plt
np.random.seed(20)

# %%
# Define the orthonormal probabilistic Hermite polynomial
def orthonormal_prob_hermite(n):
    return lambda x: hermite(n)(x/np.sqrt(2)) / np.sqrt(2**n * np.math.factorial(n))

# Define the integrand for scalar product
def scalar_int(i,j):
    return lambda x:orthonormal_prob_hermite(i)(x) * orthonormal_prob_hermite(j)(x) * np.exp(-(x**2/2))/np.sqrt(2*np.pi)

# Define the integrand for triple product
def triple_int(i,j,k):
    return lambda x:orthonormal_prob_hermite(i)(x) * orthonormal_prob_hermite(j)(x)* orthonormal_prob_hermite(k)(x) * np.exp(-(x**2/2))/np.sqrt(2*np.pi)

# Integrate to verify orthonormality
integral1, _ = quad(scalar_int(2,2), -np.inf, np.inf)
integral2, _ = quad(scalar_int(2,3), -np.inf, np.inf)
print(f"The scalar product of the orthonormal probabilistic Hermite polynomials H_2(x) and H_2(x) is approximately {integral1}")
print(f"The scalar product of the orthonormal probabilistic Hermite polynomials H_2(x) and H_3(x) is approximately {integral2}")
# Out:
# The scalar product of the orthonormal probabilistic Hermite polynomials H_2(x) and H_2(x) is approximately 1.0000000000000022
# The scalar product of the orthonormal probabilistic Hermite polynomials H_2(x) and H_3(x) is approximately 0.0

# %% [markdown]
# ##### DEFINING THE KERNEL FUNCTIONS

# %%
## defining kernel derivative function

def W2(x, l):
    R = np.abs(x) / l
    a = 1 / l
    mask1 = R <= 1
    mask2 = np.logical_and(R > 1, R < 2)
    result = np.zeros_like(R)
    result[mask1] = (2/3 - R[mask1]**2 + 0.5 * R[mask1]**3) * a
    result[mask2] = ((2 - R[mask2])**3) / 6 * a
    return result

def kernel(x,h):
    rr=np.abs(x)
    q=rr/h
    drx=x/(h*rr)
    alpha_=2/(3*h)
    mask1 = q < 1
    mask2 = np.logical_and(q >= 1, q < 2)
    # print(mask1.shape)
    result = np.zeros_like(q)
    result[mask1]=alpha_*(-3*q[mask1]+2.25*q[mask1]**2)*drx[mask1]
    result[mask2]=-alpha_*0.75*(2-q[mask2])**2*drx[mask2]
    return result

## coefficent u
def u(x):
    return 0.1*x+0.06

# %%
# Define the range of x values
x_values = np.linspace(-2, 2, 1200)

# Define a specific value for l
l = 2

# Calculate W2 and W2_d for each x value
W2_values = W2(x_values, l)
W2_d_values = kernel(x_values, l)

# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(x_values, W2_values, label='W2(x)', color='b')
plt.plot(x_values, W2_d_values, label='W2_d(x)', color='r', linestyle='--')
plt.xlabel('x')
plt.ylabel('Function value')
plt.title('Plot of W2 and W2_d vs x')
plt.legend()
plt.grid(True)
plt.show()

# %%
integral1, _ = quad(lambda x: W2(x-0,0.1), -20, 20)
print(f"The kernel is normalised and hence the integral of it over the domain should be {integral1}")
# Out:
# The kernel is normalised and hence the integral of it over the domain should be 0.999999999970019

# %%
### DEFINING CONSTANTS
T = 0.5               # Total time of integration
dt = 0.001          # Time step
N = int(T/dt)       # No of time points
a = 1               # Length of space
J = 512             # Space discretization points
P = 5               # No. of orthonarmal basis that is going to be used
d = 1.0/J
x = np.linspace(0,a,J)           # Discretization points

# Applying Initial condition
c0 = 0.25*np.sin(2*np.pi*x)                
ct = np.zeros((P,J, N+1))
for i in range(P):
    value, _ = quad_vec(lambda x:orthonormal_prob_hermite(i)(x) * c0 * np.exp(-(x**2/2))/np.sqrt(2*np.pi), -np.inf, np.inf)
    ct[i, :, 0] = value

# %% [markdown]
# ### FOR SPH

# %%
## defining constants
n_particles=J    ###  number of particles
dv = 1/n_particles   ### particle volume
rho0 = 1    ##### defining some random value of intial particle density
m_i = rho0*dv    ###### mass associated with each particle
c = 10/J    ###  radius/cutoff distance 
h = 1.2/J    ### smoothing length

#### creating neigbor list for particle
n_list = [ [] for i in range(n_particles) ]
x_dis = [ [] for i in range(n_particles) ]
for i in range(n_particles):
    for j in range(n_particles):
        if(i>j):
            k=-1
        else:
            k=1
        if(i!=j):
            if(np.linalg.norm(x[i]-x[j])<c):
                n_list[i].append(j)
                x_dis[i].append(x[i]-x[j])
            elif(a+dv-np.linalg.norm(x[i]-x[j])<c):
                n_list[i].append(j)
                x_dis[i].append(k*(a+dv-np.linalg.norm(x[i]-x[j])))
n_list=np.array(n_list)
x_dis=np.array(x_dis)

# %%
len(n_list[0])
# Out:
# 18

# %%
### function to approximate the space derivative using SPH

def SPH(c,h,n_list=n_list):
    cd=np.zeros_like(c)
    for i,neighbors in enumerate(n_list):
        c_i = c[:, i][:, np.newaxis]  # Broadcasting to create the necessary shape
        c_i = np.repeat(c_i, len(neighbors), axis=1)
        c_j=c[:,neighbors]
        cd[:,i] = np.dot((c_i-c_j), -(kernel(x_dis[i], h))) * dv
    return cd

# %%
# Precompute the scalar product values values
values=np.zeros(shape=(P,P))
for i in range(P):
    for j in range(P):
        values[i,j],_=quad_vec(lambda x: u(x)*orthonormal_prob_hermite(i)(x) * orthonormal_prob_hermite(j)(x)* np.exp(-(x**2/2))/np.sqrt(2*np.pi), -np.inf, np.inf)
        if(abs(values[i,j])<1e-15):
            values[i,j]=0

# %%
### Solving using predictor-corrector scheme
for n in range(1, N+1):
    c = ct[:, :, n-1]
    cd = SPH(c, h)
    rhs = np.zeros_like(cd)
    for i in range(P):
        for j in range(P):
            rhs[i, :] += cd[j, :] * values[i, j]

    # Predictor step
    ct_pred = ct[:, :, n-1] + rhs * dt

    # Corrector step
    cd_pred = SPH(ct_pred, h)
    rhs_pred = np.zeros_like(cd_pred)
    for i in range(P):
        for j in range(P):
            rhs_pred[i, :] += cd_pred[j, :] * values[i, j]

    ct[:, :, n] = ct[:, :, n-1] + 0.5 * (rhs + rhs_pred) * dt

    print(f"Completed the {n}^th timestep")
# Out:
# Completed the 1^th timestep
# Completed the 2^th timestep
# Completed the 3^th timestep
# Completed the 4^th timestep
# Completed the 5^th timestep
# Completed the 6^th timestep
# Completed the 7^th timestep
# Completed the 8^th timestep
# Completed the 9^th timestep
# Completed the 10^th timestep
# Completed the 11^th timestep
# Completed the 12^th timestep
# Completed the 13^th timestep
# Completed the 14^th timestep
# Completed the 15^th timestep
# Completed the 16^th timestep
# Completed the 17^th timestep
# Completed the 18^th timestep
# Completed the 19^th timestep
# Completed the 20^th timestep
# Completed the 21^th timestep
# Completed the 22^th timestep
# Completed the 23^th timestep
# Completed the 24^th timestep
# Completed the 25^th timestep
# Completed the 26^th timestep
# Completed the 27^th timestep
# Completed the 28^th timestep
# Completed the 29^th timestep
# Completed the 30^th timestep
# Completed the 31^th timestep
# Completed the 32^th timestep
# Completed the 33^th timestep
# Completed the 34^th timestep
# Completed the 35^th timestep
# Completed the 36^th timestep
# Completed the 37^th timestep
# Completed the 38^th timestep
# Completed the 39^th timestep
# Completed the 40^th timestep
# Completed the 41^th timestep
# Completed the 42^th timestep
# Completed the 43^th timestep
# Completed the 44^th timestep
# Completed the 45^th timestep
# Completed the 46^th timestep
# Completed the 47^th timestep
# Completed the 48^th timestep
# Completed the 49^th timestep
# Completed the 50^th timestep
# Completed the 51^th timestep
# Completed the 52^th timestep
# Completed the 53^th timestep
# Completed the 54^th timestep
# Completed the 55^th timestep
# Completed the 56^th timestep
# Completed the 57^th timestep
# Completed the 58^th timestep
# Completed the 59^th timestep
# Completed the 60^th timestep
# Completed the 61^th timestep
# Completed the 62^th timestep
# Completed the 63^th timestep
# Completed the 64^th timestep
# Completed the 65^th timestep
# Completed the 66^th timestep
# Completed the 67^th timestep
# Completed the 68^th timestep
# Completed the 69^th timestep
# Completed the 70^th timestep
# Completed the 71^th timestep
# Completed the 72^th timestep
# Completed the 73^th timestep
# Completed the 74^th timestep
# Completed the 75^th timestep
# Completed the 76^th timestep
# Completed the 77^th timestep
# Completed the 78^th timestep
# Completed the 79^th timestep
# Completed the 80^th timestep
# Completed the 81^th timestep
# Completed the 82^th timestep
# Completed the 83^th timestep
# Completed the 84^th timestep
# Completed the 85^th timestep
# Completed the 86^th timestep
# Completed the 87^th timestep
# Completed the 88^th timestep
# Completed the 89^th timestep
# Completed the 90^th timestep
# Completed the 91^th timestep
# Completed the 92^th timestep
# Completed the 93^th timestep
# Completed the 94^th timestep
# Completed the 95^th timestep
# Completed the 96^th timestep
# Completed the 97^th timestep
# Completed the 98^th timestep
# Completed the 99^th timestep
# Completed the 100^th timestep
# Completed the 101^th timestep
# Completed the 102^th timestep
# Completed the 103^th timestep
# Completed the 104^th timestep
# Completed the 105^th timestep
# Completed the 106^th timestep
# Completed the 107^th timestep
# Completed the 108^th timestep
# Completed the 109^th timestep
# Completed the 110^th timestep
# Completed the 111^th timestep
# Completed the 112^th timestep
# Completed the 113^th timestep
# Completed the 114^th timestep
# Completed the 115^th timestep
# Completed the 116^th timestep
# Completed the 117^th timestep
# Completed the 118^th timestep
# Completed the 119^th timestep
# Completed the 120^th timestep
# Completed the 121^th timestep
# Completed the 122^th timestep
# Completed the 123^th timestep
# Completed the 124^th timestep
# Completed the 125^th timestep
# Completed the 126^th timestep
# Completed the 127^th timestep
# Completed the 128^th timestep
# Completed the 129^th timestep
# Completed the 130^th timestep
# Completed the 131^th timestep
# Completed the 132^th timestep
# Completed the 133^th timestep
# Completed the 134^th timestep
# Completed the 135^th timestep
# Completed the 136^th timestep
# Completed the 137^th timestep
# Completed the 138^th timestep
# Completed the 139^th timestep
# Completed the 140^th timestep
# Completed the 141^th timestep
# Completed the 142^th timestep
# Completed the 143^th timestep
# Completed the 144^th timestep
# Completed the 145^th timestep
# Completed the 146^th timestep
# Completed the 147^th timestep
# Completed the 148^th timestep
# Completed the 149^th timestep
# Completed the 150^th timestep
# Completed the 151^th timestep
# Completed the 152^th timestep
# Completed the 153^th timestep
# Completed the 154^th timestep
# Completed the 155^th timestep
# Completed the 156^th timestep
# Completed the 157^th timestep
# Completed the 158^th timestep
# Completed the 159^th timestep
# Completed the 160^th timestep
# Completed the 161^th timestep
# Completed the 162^th timestep
# Completed the 163^th timestep
# Completed the 164^th timestep
# Completed the 165^th timestep
# Completed the 166^th timestep
# Completed the 167^th timestep
# Completed the 168^th timestep
# Completed the 169^th timestep
# Completed the 170^th timestep
# Completed the 171^th timestep
# Completed the 172^th timestep
# Completed the 173^th timestep
# Completed the 174^th timestep
# Completed the 175^th timestep
# Completed the 176^th timestep
# Completed the 177^th timestep
# Completed the 178^th timestep
# Completed the 179^th timestep
# Completed the 180^th timestep
# Completed the 181^th timestep
# Completed the 182^th timestep
# Completed the 183^th timestep
# Completed the 184^th timestep
# Completed the 185^th timestep
# Completed the 186^th timestep
# Completed the 187^th timestep
# Completed the 188^th timestep
# Completed the 189^th timestep
# Completed the 190^th timestep
# Completed the 191^th timestep
# Completed the 192^th timestep
# Completed the 193^th timestep
# Completed the 194^th timestep
# Completed the 195^th timestep
# Completed the 196^th timestep
# Completed the 197^th timestep
# Completed the 198^th timestep
# Completed the 199^th timestep
# Completed the 200^th timestep
# Completed the 201^th timestep
# Completed the 202^th timestep
# Completed the 203^th timestep
# Completed the 204^th timestep
# Completed the 205^th timestep
# Completed the 206^th timestep
# Completed the 207^th timestep
# Completed the 208^th timestep
# Completed the 209^th timestep
# Completed the 210^th timestep
# Completed the 211^th timestep
# Completed the 212^th timestep
# Completed the 213^th timestep
# Completed the 214^th timestep
# Completed the 215^th timestep
# Completed the 216^th timestep
# Completed the 217^th timestep
# Completed the 218^th timestep
# Completed the 219^th timestep
# Completed the 220^th timestep
# Completed the 221^th timestep
# Completed the 222^th timestep
# Completed the 223^th timestep
# Completed the 224^th timestep
# Completed the 225^th timestep
# Completed the 226^th timestep
# Completed the 227^th timestep
# Completed the 228^th timestep
# Completed the 229^th timestep
# Completed the 230^th timestep
# Completed the 231^th timestep
# Completed the 232^th timestep
# Completed the 233^th timestep
# Completed the 234^th timestep
# Completed the 235^th timestep
# Completed the 236^th timestep
# Completed the 237^th timestep
# Completed the 238^th timestep
# Completed the 239^th timestep
# Completed the 240^th timestep
# Completed the 241^th timestep
# Completed the 242^th timestep
# Completed the 243^th timestep
# Completed the 244^th timestep
# Completed the 245^th timestep
# Completed the 246^th timestep
# Completed the 247^th timestep
# Completed the 248^th timestep
# Completed the 249^th timestep
# Completed the 250^th timestep
# Completed the 251^th timestep
# Completed the 252^th timestep
# Completed the 253^th timestep
# Completed the 254^th timestep
# Completed the 255^th timestep
# Completed the 256^th timestep
# Completed the 257^th timestep
# Completed the 258^th timestep
# Completed the 259^th timestep
# Completed the 260^th timestep
# Completed the 261^th timestep
# Completed the 262^th timestep
# Completed the 263^th timestep
# Completed the 264^th timestep
# Completed the 265^th timestep
# Completed the 266^th timestep
# Completed the 267^th timestep
# Completed the 268^th timestep
# Completed the 269^th timestep
# Completed the 270^th timestep
# Completed the 271^th timestep
# Completed the 272^th timestep
# Completed the 273^th timestep
# Completed the 274^th timestep
# Completed the 275^th timestep
# Completed the 276^th timestep
# Completed the 277^th timestep
# Completed the 278^th timestep
# Completed the 279^th timestep
# Completed the 280^th timestep
# Completed the 281^th timestep
# Completed the 282^th timestep
# Completed the 283^th timestep
# Completed the 284^th timestep
# Completed the 285^th timestep
# Completed the 286^th timestep
# Completed the 287^th timestep
# Completed the 288^th timestep
# Completed the 289^th timestep
# Completed the 290^th timestep
# Completed the 291^th timestep
# Completed the 292^th timestep
# Completed the 293^th timestep
# Completed the 294^th timestep
# Completed the 295^th timestep
# Completed the 296^th timestep
# Completed the 297^th timestep
# Completed the 298^th timestep
# Completed the 299^th timestep
# Completed the 300^th timestep
# Completed the 301^th timestep
# Completed the 302^th timestep
# Completed the 303^th timestep
# Completed the 304^th timestep
# Completed the 305^th timestep
# Completed the 306^th timestep
# Completed the 307^th timestep
# Completed the 308^th timestep
# Completed the 309^th timestep
# Completed the 310^th timestep
# Completed the 311^th timestep
# Completed the 312^th timestep
# Completed the 313^th timestep
# Completed the 314^th timestep
# Completed the 315^th timestep
# Completed the 316^th timestep
# Completed the 317^th timestep
# Completed the 318^th timestep
# Completed the 319^th timestep
# Completed the 320^th timestep
# Completed the 321^th timestep
# Completed the 322^th timestep
# Completed the 323^th timestep
# Completed the 324^th timestep
# Completed the 325^th timestep
# Completed the 326^th timestep
# Completed the 327^th timestep
# Completed the 328^th timestep
# Completed the 329^th timestep
# Completed the 330^th timestep
# Completed the 331^th timestep
# Completed the 332^th timestep
# Completed the 333^th timestep
# Completed the 334^th timestep
# Completed the 335^th timestep
# Completed the 336^th timestep
# Completed the 337^th timestep
# Completed the 338^th timestep
# Completed the 339^th timestep
# Completed the 340^th timestep
# Completed the 341^th timestep
# Completed the 342^th timestep
# Completed the 343^th timestep
# Completed the 344^th timestep
# Completed the 345^th timestep
# Completed the 346^th timestep
# Completed the 347^th timestep
# Completed the 348^th timestep
# Completed the 349^th timestep
# Completed the 350^th timestep
# Completed the 351^th timestep
# Completed the 352^th timestep
# Completed the 353^th timestep
# Completed the 354^th timestep
# Completed the 355^th timestep
# Completed the 356^th timestep
# Completed the 357^th timestep
# Completed the 358^th timestep
# Completed the 359^th timestep
# Completed the 360^th timestep
# Completed the 361^th timestep
# Completed the 362^th timestep
# Completed the 363^th timestep
# Completed the 364^th timestep
# Completed the 365^th timestep
# Completed the 366^th timestep
# Completed the 367^th timestep
# Completed the 368^th timestep
# Completed the 369^th timestep
# Completed the 370^th timestep
# Completed the 371^th timestep
# Completed the 372^th timestep
# Completed the 373^th timestep
# Completed the 374^th timestep
# Completed the 375^th timestep
# Completed the 376^th timestep
# Completed the 377^th timestep
# Completed the 378^th timestep
# Completed the 379^th timestep
# Completed the 380^th timestep
# Completed the 381^th timestep
# Completed the 382^th timestep
# Completed the 383^th timestep
# Completed the 384^th timestep
# Completed the 385^th timestep
# Completed the 386^th timestep
# Completed the 387^th timestep
# Completed the 388^th timestep
# Completed the 389^th timestep
# Completed the 390^th timestep
# Completed the 391^th timestep
# Completed the 392^th timestep
# Completed the 393^th timestep
# Completed the 394^th timestep
# Completed the 395^th timestep
# Completed the 396^th timestep
# Completed the 397^th timestep
# Completed the 398^th timestep
# Completed the 399^th timestep
# Completed the 400^th timestep
# Completed the 401^th timestep
# Completed the 402^th timestep
# Completed the 403^th timestep
# Completed the 404^th timestep
# Completed the 405^th timestep
# Completed the 406^th timestep
# Completed the 407^th timestep
# Completed the 408^th timestep
# Completed the 409^th timestep
# Completed the 410^th timestep
# Completed the 411^th timestep
# Completed the 412^th timestep
# Completed the 413^th timestep
# Completed the 414^th timestep
# Completed the 415^th timestep
# Completed the 416^th timestep
# Completed the 417^th timestep
# Completed the 418^th timestep
# Completed the 419^th timestep
# Completed the 420^th timestep
# Completed the 421^th timestep
# Completed the 422^th timestep
# Completed the 423^th timestep
# Completed the 424^th timestep
# Completed the 425^th timestep
# Completed the 426^th timestep
# Completed the 427^th timestep
# Completed the 428^th timestep
# Completed the 429^th timestep
# Completed the 430^th timestep
# Completed the 431^th timestep
# Completed the 432^th timestep
# Completed the 433^th timestep
# Completed the 434^th timestep
# Completed the 435^th timestep
# Completed the 436^th timestep
# Completed the 437^th timestep
# Completed the 438^th timestep
# Completed the 439^th timestep
# Completed the 440^th timestep
# Completed the 441^th timestep
# Completed the 442^th timestep
# Completed the 443^th timestep
# Completed the 444^th timestep
# Completed the 445^th timestep
# Completed the 446^th timestep
# Completed the 447^th timestep
# Completed the 448^th timestep
# Completed the 449^th timestep
# Completed the 450^th timestep
# Completed the 451^th timestep
# Completed the 452^th timestep
# Completed the 453^th timestep
# Completed the 454^th timestep
# Completed the 455^th timestep
# Completed the 456^th timestep
# Completed the 457^th timestep
# Completed the 458^th timestep
# Completed the 459^th timestep
# Completed the 460^th timestep
# Completed the 461^th timestep
# Completed the 462^th timestep
# Completed the 463^th timestep
# Completed the 464^th timestep
# Completed the 465^th timestep
# Completed the 466^th timestep
# Completed the 467^th timestep
# Completed the 468^th timestep
# Completed the 469^th timestep
# Completed the 470^th timestep
# Completed the 471^th timestep
# Completed the 472^th timestep
# Completed the 473^th timestep
# Completed the 474^th timestep
# Completed the 475^th timestep
# Completed the 476^th timestep
# Completed the 477^th timestep
# Completed the 478^th timestep
# Completed the 479^th timestep
# Completed the 480^th timestep
# Completed the 481^th timestep
# Completed the 482^th timestep
# Completed the 483^th timestep
# Completed the 484^th timestep
# Completed the 485^th timestep
# Completed the 486^th timestep
# Completed the 487^th timestep
# Completed the 488^th timestep
# Completed the 489^th timestep
# Completed the 490^th timestep
# Completed the 491^th timestep
# Completed the 492^th timestep
# Completed the 493^th timestep
# Completed the 494^th timestep
# Completed the 495^th timestep
# Completed the 496^th timestep
# Completed the 497^th timestep
# Completed the 498^th timestep
# Completed the 499^th timestep
# Completed the 500^th timestep

# %%
#### LET'S CALCULATE mean 
def calculate_mean(ct,P,x):
    f=0
    for i in range(P):
        f+=orthonormal_prob_hermite(i)(x) * ct[i,:,:]
    return  f

value,_=quad_vec(lambda x:calculate_mean(ct,P,x) * np.exp(-0.5*(x**2))/np.sqrt(2*np.pi), -np.inf, np.inf)
u_mean=value

# %%
# set font sizes and math font
plt.rcParams['font.size'] = 30
plt.rcParams['mathtext.fontset'] = 'dejavuserif'

# create figure
fig1 = plt.figure(figsize=(24, 8), dpi=200)

# plot heatmap
heatmap = plt.imshow(u_mean, aspect='auto', cmap='jet')

# add vertical lines at t = 150, 250, 350
for t in [150, 250, 350]:
    plt.axvline(x=t, color='white', linestyle='--', linewidth=2)

# add horizontal lines at x = 150, 350
for y in [150, 350]:
    plt.axhline(y=y, color='white', linestyle='--', linewidth=2)

# labels and colorbar
plt.xlabel('Time (T)')
plt.ylabel('Spatial dimension (x)')
cbar = plt.colorbar(heatmap)
cbar.set_label('Values')

plt.show()

# %%
import pickle
with open('results_exp1_MEAN_mcs.pkl', 'rb') as file:
    mean_mcs=pickle.load(file)
with open('results_exp1_STD_mcs.pkl', 'rb') as file:
    std_mcs=pickle.load(file)

# %%
plt.rcParams['font.size'] = 20
# ------------------------------------------------------
# 1) Prepare your data & coordinates
# ------------------------------------------------------
# u_mean: 2D array of shape (nx, nt)
# x:    1D array (length nx) giving the spatial grid coordinates
# t:    1D array (length nt) giving the time grid coordinates

# Example placeholders (replace with your real arrays):
x = np.linspace(0, 1, u_mean.shape[0])
t = np.linspace(0, 0.5, u_mean.shape[1])

# ------------------------------------------------------
# 2) Choose five slices in time and five in space
# ------------------------------------------------------
fixed_times = [150, 250, 350]   # time-coordinates you want to hold fixed
fixed_xs    = [150, 350]   # spatial-coordinates you want to hold fixed

# find the nearest indices in your grid
time_inds = [np.abs(ti) for ti in fixed_times]
x_inds    = [np.abs(xi) for xi in fixed_xs]

# ------------------------------------------------------
# 3) Plot u(x) at each fixed time
# ------------------------------------------------------
for ti, tval in zip(time_inds, fixed_times):
    plt.figure(figsize=(5, 4), dpi=200)
    plt.plot(x, u_mean[:, ti], linewidth=2)
    plt.plot(x, mean_mcs[:, ti], linewidth=2)
    plt.title(f'Time = {tval/1000}s')
    plt.xlabel('Spatial coordinate x')
    plt.ylabel('u')
    plt.tight_layout()
    plt.show()

# ------------------------------------------------------
# 4) Plot u(t) at each fixed spatial location
# ------------------------------------------------------
i=0
for xi, xval in zip(x_inds, fixed_xs):
    plt.figure(figsize=(5, 4), dpi=200)
    plt.plot(t, u_mean[xi, :], linewidth=2)
    plt.plot(t, mean_mcs[xi, :], linewidth=2)
    plt.title(f'x = {xval}')
    plt.xlabel('Time (T)')
    plt.ylabel('u')
    if(i==0):
        plt.ylim(0.20,0.26)
    else:
        plt.ylim(-0.240,-0.220)
        
    i+=1
    plt.tight_layout()
    plt.show()

# %%
#### LET'S CALCULATE variance
def calculate_sq(ct,P,u_mean,x):
    f=0
    for i in range(P):
        f+=orthonormal_prob_hermite(i)(x) * ct[i,:,:]
    return  (f-u_mean)**2

value,_=quad_vec(lambda x:calculate_sq(ct,P,u_mean,x) * np.exp(-(x**2/2))/np.sqrt(2*np.pi), -np.inf, np.inf)
u_std=np.sqrt(value)

# %%
# set font sizes and math font
plt.rcParams['font.size'] = 30
plt.rcParams['mathtext.fontset'] = 'dejavuserif'

# create figure
fig1 = plt.figure(figsize=(24, 8), dpi=200)

# plot heatmap
heatmap = plt.imshow(u_std, aspect='auto', cmap='jet')

# add vertical lines at t = 150, 250, 350
for t in [150, 250, 350]:
    plt.axvline(x=t, color='white', linestyle='--', linewidth=2)

# add horizontal lines at x = 150, 350
for y in [150, 350]:
    plt.axhline(y=y, color='white', linestyle='--', linewidth=2)

# labels and colorbar
plt.xlabel('Time (T)')
plt.ylabel('Spatial dimension (x)')
cbar = plt.colorbar(heatmap)
cbar.set_label('Values')

plt.show()

# %%
plt.rcParams['font.size'] = 20
# ------------------------------------------------------
# 1) Prepare your data & coordinates
# ------------------------------------------------------
# u_mean: 2D array of shape (nx, nt)
# x:    1D array (length nx) giving the spatial grid coordinates
# t:    1D array (length nt) giving the time grid coordinates

# Example placeholders (replace with your real arrays):
x = np.linspace(0, 1, u_mean.shape[0])
t = np.linspace(0, 0.5, u_mean.shape[1])

# ------------------------------------------------------
# 2) Choose five slices in time and five in space
# ------------------------------------------------------
fixed_times = [150, 250, 350]   # time-coordinates you want to hold fixed
fixed_xs    = [150, 350]   # spatial-coordinates you want to hold fixed

# find the nearest indices in your grid
time_inds = [np.abs(ti) for ti in fixed_times]
x_inds    = [np.abs(xi) for xi in fixed_xs]

# ------------------------------------------------------
# 3) Plot u(x) at each fixed time
# ------------------------------------------------------
for ti, tval in zip(time_inds, fixed_times):
    plt.figure(figsize=(5, 4), dpi=200)
    plt.plot(x, u_std[:, ti], linewidth=2)
    plt.plot(x, std_mcs[:, ti], linewidth=2)
    plt.title(f'Time = {tval/1000}s')
    plt.xlabel('Spatial coordinate x')
    plt.ylabel('u')
    plt.tight_layout()
    plt.show()

# ------------------------------------------------------
# 4) Plot u(t) at each fixed spatial location
# ------------------------------------------------------
for xi, xval in zip(x_inds, fixed_xs):
    plt.figure(figsize=(5, 4), dpi=200)
    plt.plot(t, u_std[xi, :], linewidth=2)
    plt.plot(t, std_mcs[xi, :], linewidth=2)
    plt.title(f'x = {xval}')
    plt.xlabel('Time (T)')
    plt.ylabel('u')
    plt.ylim(np.min(std_mcs[xi, :]), 2*np.max(std_mcs[xi, :]))
    plt.tight_layout()
    plt.show()

# %%
import pickle
with open('results_exp1_0.pkl', 'wb') as file:
    pickle.dump(ct, file)
