# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
import h5py

# %%
ut=None
# Open the MATLAB v7.3 .mat file
with h5py.File('results_mcs2_test.mat', 'r') as f:
    # Explore the keys in the file
    print(f.keys())
    # Access specific datasets
    ut = f['results_single'][:]
    ut=ut.astype(np.float16)
    print(ut.shape)
# Out:
# <KeysViewHDF5 ['results_single']>
# (101, 2500, 2, 2501)

# %%
with h5py.File('results_mcs2_test2.mat', 'r') as f:
    # Explore the keys in the file
    print(f.keys())
    # Access specific datasets
    ut = np.concatenate([f['results_single'][:], ut], axis=3).astype(np.float16)
    print(ut.shape)
# Out:
# <KeysViewHDF5 ['results_single']>
# (101, 2500, 2, 5001)

# %%
u_init=ut[0,:,:,:]
with open('u_init.pkl', 'wb') as file:
    pickle.dump(u_init, file)

# %%
ut_mean1=ut.mean(axis=3)
ut_std1=ut.std(axis=3)
del ut

# %%
# with open('results_mcs_new2.pkl', 'rb') as file:
#     ut = np.array(pickle.load(file),dtype=np.float16)

# %%
# ut_mean2=ut.mean(axis=0)
# ut_std2=ut.std(axis=0)
# del ut

# %%
# ut_mean=(ut_mean1+ut_mean1)/2
# ut_std=np.sqrt((ut_std1**2+ut_std2**2)/2)

# %%
J=2500

# %%
ut_mean1.shape
# Out:
# (101, 2500, 2)

# %%
# ut_mean=ut.mean(axis=0)
# ut_std=ut.std(axis=0)

# %%
# ut2_mean = ut2.mean(axis=0)
# ut2_std = ut2.std(axis=0)

# %%
plt.subplots(figsize=(20, 4))
u_plot = (ut_mean1[0, :, 1]).reshape((int(np.sqrt(J)), int(np.sqrt(J))))
plt.subplot(1, 5, 1)
heatmap = plt.imshow(u_plot, aspect='auto', cmap='jet')
plt.xlabel('Spatial dimension (y)')
plt.ylabel('Spatial dimension (x)')
plt.title(f'U mean at time {0}', fontweight='bold')
cbar = plt.colorbar(heatmap)

plt.subplot(1, 5, 2)
u_plot = (ut_mean1[25, :, 1]).reshape((int(np.sqrt(J)), int(np.sqrt(J))))
heatmap = plt.imshow(u_plot, aspect='auto', cmap='jet')
plt.xlabel('Spatial dimension (y)')
plt.ylabel('Spatial dimension (x)')
plt.title(f'U mean at time {0.05}', fontweight='bold')
cbar = plt.colorbar(heatmap)

plt.subplot(1, 5, 3)
u_plot = (ut_mean1[50, :, 1]).reshape((int(np.sqrt(J)), int(np.sqrt(J))))
heatmap = plt.imshow(u_plot, aspect='auto', cmap='jet')
plt.xlabel('Spatial dimension (y)')
plt.ylabel('Spatial dimension (x)')
plt.title(f'U mean at time {0.10}', fontweight='bold')
cbar = plt.colorbar(heatmap)

plt.subplot(1, 5, 4)
u_plot = ut_mean1[75, :, 1].reshape((int(np.sqrt(J)), int(np.sqrt(J))))
heatmap = plt.imshow(u_plot, aspect='auto', cmap='jet')
plt.xlabel('Spatial dimension (y)')
plt.ylabel('Spatial dimension (x)')
plt.title(f'U mean at time {0.15}', fontweight='bold')
cbar = plt.colorbar(heatmap)

plt.subplot(1, 5, 5)
u_plot = ut_mean1[100, :, 1].reshape((int(np.sqrt(J)), int(np.sqrt(J))))
heatmap = plt.imshow(u_plot, aspect='auto', cmap='jet')
plt.xlabel('Spatial dimension (y)')
plt.ylabel('Spatial dimension (x)')
plt.title(f'U mean at time {0.20}', fontweight='bold')
cbar = plt.colorbar(heatmap)

# Add colorbar with legend
cbar.set_label('Values')

# Save the figure
plt.savefig('u_mean_mcs2_1.png', dpi=300, bbox_inches='tight')

# Show the figure
plt.show()

# %%
plt.subplots(figsize=(20, 4))
u_plot = (ut_std1[0, :, 1]).reshape((int(np.sqrt(J)), int(np.sqrt(J))))
plt.subplot(1, 5, 1)
heatmap = plt.imshow(u_plot, aspect='auto', cmap='jet')
plt.xlabel('Spatial dimension (y)')
plt.ylabel('Spatial dimension (x)')
plt.title(f'U std at time {0}', fontweight='bold')
cbar = plt.colorbar(heatmap)

plt.subplot(1, 5, 2)
u_plot = (ut_std1[25, :, 1]).reshape((int(np.sqrt(J)), int(np.sqrt(J))))
heatmap = plt.imshow(u_plot, aspect='auto', cmap='jet')
plt.xlabel('Spatial dimension (y)')
plt.ylabel('Spatial dimension (x)')
plt.title(f'U std at time {0.05}', fontweight='bold')
cbar = plt.colorbar(heatmap)

plt.subplot(1, 5, 3)
u_plot = (ut_std1[50, :, 1]).reshape((int(np.sqrt(J)), int(np.sqrt(J))))
heatmap = plt.imshow(u_plot, aspect='auto', cmap='jet')
plt.xlabel('Spatial dimension (y)')
plt.ylabel('Spatial dimension (x)')
plt.title(f'U std at time {0.10}', fontweight='bold')
cbar = plt.colorbar(heatmap)

plt.subplot(1, 5, 4)
u_plot = ut_std1[75, :, 1].reshape((int(np.sqrt(J)), int(np.sqrt(J))))
heatmap = plt.imshow(u_plot, aspect='auto', cmap='jet')
plt.xlabel('Spatial dimension (y)')
plt.ylabel('Spatial dimension (x)')
plt.title(f'U std at time {0.15}', fontweight='bold')
cbar = plt.colorbar(heatmap)

plt.subplot(1, 5, 5)
u_plot = ut_std1[100, :, 1].reshape((int(np.sqrt(J)), int(np.sqrt(J))))
heatmap = plt.imshow(u_plot, aspect='auto', cmap='jet')
plt.xlabel('Spatial dimension (y)')
plt.ylabel('Spatial dimension (x)')
plt.title(f'U std at time {0.20}', fontweight='bold')
cbar = plt.colorbar(heatmap)

# Add colorbar with legend
cbar.set_label('Values')

# Save the figure
plt.savefig('u_std_mcs2_1.png', dpi=300, bbox_inches='tight')

# Show the figure
plt.show()

# %%
# Interpolation factor
zoom_factor = 2  # Increase for higher smoothing

plt.figure(figsize=(20, 4))
for i, time in enumerate([0, 0.075, 0.15, 0.225, 0.3]):
    plt.subplot(1, 5, i+1)
    
    # Select the data slice for the time you want to plot
    u_plot = ut_std[1,:,i*25].reshape((int(np.sqrt(J)), int(np.sqrt(J))))
    
    # Interpolating the data to make it smoother
    u_plot = u_plot.astype(np.float32)
    u_plot_smooth = zoom(u_plot, zoom_factor)
    
    # Plotting
    heatmap = plt.imshow(u_plot_smooth, aspect='auto', cmap='jet')
    plt.xlabel('Spatial dimension (y)')
    plt.ylabel('Spatial dimension (x)')
    plt.title(f'U std at time {time:.2f}', fontsize=12, fontweight='bold')
    plt.colorbar(heatmap).set_label('Values')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 9
#       6 plt.subplot(1, 5, i+1)
#       8 # Select the data slice for the time you want to plot
# ----> 9 u_plot = ut_std[1,:,i*25].reshape((int(np.sqrt(J)), int(np.sqrt(J))))
#      11 # Interpolating the data to make it smoother
#      12 u_plot = u_plot.astype(np.float32)
#
# NameError: name 'ut_std' is not defined

# %%
# plt.subplots(figsize=(20, 4))
# u_plot=ut2[1,0,:,0].reshape((int(np.sqrt(J)), int(np.sqrt(J))))
# plt.subplot(1,5,1)
# heatmap=plt.imshow(u_plot, aspect='auto', cmap='jet')
# plt.xlabel('Spatial dimension (y)')
# plt.ylabel('Spatial dimension (x)')
# plt.title(f'at time {0}', fontweight='bold')
# cbar = plt.colorbar(heatmap)
# plt.subplot(1,5,2)
# u_plot=ut2[1,0,:,10].reshape((int(np.sqrt(J)), int(np.sqrt(J))))
# heatmap=plt.imshow(u_plot, aspect='auto', cmap='jet')
# plt.xlabel('Spatial dimension (y)')
# plt.ylabel('Spatial dimension (x)')
# plt.title(f'at time {0.05}', fontweight='bold')
# cbar = plt.colorbar(heatmap)
# plt.subplot(1,5,3)
# u_plot=ut2[1,0,:,20].reshape((int(np.sqrt(J)), int(np.sqrt(J))))
# heatmap=plt.imshow(u_plot, aspect='auto', cmap='jet')
# plt.xlabel('Spatial dimension (y)')
# plt.ylabel('Spatial dimension (x)')
# plt.title(f'at time {0.10}', fontweight='bold')
# cbar = plt.colorbar(heatmap)
# plt.subplot(1,5,4)
# u_plot=ut2[1,0,:,30].reshape((int(np.sqrt(J)), int(np.sqrt(J))))
# heatmap=plt.imshow(u_plot, aspect='auto', cmap='jet')
# plt.xlabel('Spatial dimension (y)')
# plt.ylabel('Spatial dimension (x)')
# plt.title(f'at time {0.15}', fontweight='bold')
# cbar = plt.colorbar(heatmap)
# plt.subplot(1,5,5)
# u_plot=ut2[1,0,:,40].reshape((int(np.sqrt(J)), int(np.sqrt(J))))
# heatmap=plt.imshow(u_plot, aspect='auto', cmap='jet')
# plt.xlabel('Spatial dimension (y)')
# plt.ylabel('Spatial dimension (x)')
# plt.title(f'at time {0.20}', fontweight='bold')
# cbar = plt.colorbar(heatmap)
# # Add colorbar with legend
# # cbar = plt.colorbar(heatmap)
# cbar.set_label('Values')
# plt.show()

# %%
# plt.subplots(figsize=(20, 4))
# u_plot=np.abs(ut2[1,0,:,0]-ut_mean[1,:,0]).reshape((int(np.sqrt(J)), int(np.sqrt(J))))
# plt.subplot(1,5,1)
# heatmap=plt.imshow(u_plot, aspect='auto', cmap='jet')
# plt.xlabel('Spatial dimension (y)')
# plt.ylabel('Spatial dimension (x)')
# plt.title(f'at time {0}', fontweight='bold')
# cbar = plt.colorbar(heatmap)
# plt.subplot(1,5,2)
# u_plot=np.abs(ut2[1,0,:,10]-ut_mean[1,:,10]).reshape((int(np.sqrt(J)), int(np.sqrt(J))))
# heatmap=plt.imshow(u_plot, aspect='auto', cmap='jet')
# plt.xlabel('Spatial dimension (y)')
# plt.ylabel('Spatial dimension (x)')
# plt.title(f'at time {0.05}', fontweight='bold')
# cbar = plt.colorbar(heatmap)
# plt.subplot(1,5,3)
# u_plot=np.abs(ut2[1,0,:,20]-ut_mean[1,:,20]).reshape((int(np.sqrt(J)), int(np.sqrt(J))))
# heatmap=plt.imshow(u_plot, aspect='auto', cmap='jet')
# plt.xlabel('Spatial dimension (y)')
# plt.ylabel('Spatial dimension (x)')
# plt.title(f'at time {0.10}', fontweight='bold')
# cbar = plt.colorbar(heatmap)
# plt.subplot(1,5,4)
# u_plot=np.abs(ut2[1,0,:,30]-ut_mean[1,:,30]).reshape((int(np.sqrt(J)), int(np.sqrt(J))))
# heatmap=plt.imshow(u_plot, aspect='auto', cmap='jet')
# plt.xlabel('Spatial dimension (y)')
# plt.ylabel('Spatial dimension (x)')
# plt.title(f'at time {0.15}', fontweight='bold')
# cbar = plt.colorbar(heatmap)
# plt.subplot(1,5,5)
# u_plot=np.abs(ut2[1,0,:,40]-ut_mean[1,:,40]).reshape((int(np.sqrt(J)), int(np.sqrt(J))))
# heatmap=plt.imshow(u_plot, aspect='auto', cmap='jet')
# plt.xlabel('Spatial dimension (y)')
# plt.ylabel('Spatial dimension (x)')
# plt.title(f'at time {0.20}', fontweight='bold')
# cbar = plt.colorbar(heatmap)
# # Add colorbar with legend
# # cbar = plt.colorbar(heatmap)
# cbar.set_label('Values')
# plt.show()
